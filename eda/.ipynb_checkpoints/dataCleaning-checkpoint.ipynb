# %%
from pyforest import *

# %%
# import dataset that has cities and counties from US
cities = pd.read_csv(r'/Users/dillorr/defaultRate/dillon/defaultRate/data/usCities/simplemapsPro/uscities.csv', encoding = "ISO-8859-1")
cities.head()
# Out:
#                          city                  city_ascii city_alt state_id  \
# 0                Rodena Beach                Rodena Beach      NaN       WA
# 1                 South Creek                 South Creek      NaN       WA
# 2                      Toroda                      Toroda      NaN       WA
# 3  American Lake Garden Tract  American Lake Garden Tract      NaN       WA
# 4                      Roslyn                      Roslyn      NaN       WA
#
#    state_name  county_fips county_name county_fips_all county_name_all  \
# 0  Washington        53029      Island           53029          Island
# 1  Washington        53053      Pierce           53053          Pierce
# 2  Washington        53019       Ferry           53019           Ferry
# 3  Washington        53053      Pierce           53053          Pierce
# 4  Washington        53037    Kittitas           53037        Kittitas
#
#        lat  ...  education_college_or_above  labor_force_participation  \
# ...

# %%
# sort by state name
citiesByState = cities.sort_values(by=['state_name'])
citiesByState.head()
# Out:
#              city  city_ascii city_alt state_id state_name  county_fips  \
# 56103       Toxey       Toxey      NaN       AL    Alabama         1023
# 55903      Wilmer      Wilmer      NaN       AL    Alabama         1097
# 55904      Moshat      Moshat      NaN       AL    Alabama         1019
# 55905  Skinnerton  Skinnerton      NaN       AL    Alabama         1035
# 55906   Edgewater   Edgewater      NaN       AL    Alabama         1073
#
#       county_name county_fips_all county_name_all      lat  ...  \
# 56103     Choctaw           01023         Choctaw  31.9107  ...
# 55903      Mobile           01097          Mobile  30.8232  ...
# 55904    Cherokee           01019        Cherokee  34.1187  ...
# 55905     Conecuh     01035|01099  Conecuh|Monroe  31.6699  ...
# 55906   Jefferson           01073       Jefferson  33.5286  ...
#
#        education_college_or_above  labor_force_participation  \
# 56103                        26.8                       54.5
# ...

# %%
# inspect dataset for missing values
cities.isnull().sum()
# Out:
# city                                0
# city_ascii                          0
# city_alt                       107316
# state_id                            0
# state_name                          0
# county_fips                         0
# county_name                         0
# county_fips_all                     0
# county_name_all                     0
# lat                                 0
# lng                                 0
# population                      76405
# population_proper               76405
# density                             0
# source                              0
# military                            0
# incorporated                        0
# timezone                            0
# ranking                             0
# zips                                8
# id                                  0
# age_median                      76859
# male                            76884
# female                          76884
# married                         76884
# ...

# %%
# looking at null value
cities[cities.isna().any(axis=1)]
# Out:
#                               city                  city_ascii city_alt  \
# 0                     Rodena Beach                Rodena Beach      NaN
# 1                      South Creek                 South Creek      NaN
# 2                           Toroda                      Toroda      NaN
# 3       American Lake Garden Tract  American Lake Garden Tract      NaN
# 4                           Roslyn                      Roslyn      NaN
# ...                            ...                         ...      ...
# 107543                        Usta                        Usta      NaN
# 107544                      Walker                      Walker      NaN
# 107545                        Weta                        Weta      NaN
# 107546                     Buffalo                     Buffalo      NaN
# 107547                       Igloo                       Igloo      NaN
#
#        state_id    state_name  county_fips county_name county_fips_all  \
# ...

# %%
# import merged dataset from zipMerge
df = pd.read_csv(r'/Users/dillorr/defaultRate/dillon/defaultRate/data/merged/CDRCombined.csv', 
                     encoding = "ISO-8859-1")
df.head()
# Out:
#    opeid stateabv    state      county            city  \
# 0   1002       AL  Alabama     Madison          Normal
# 1   1003       AL  Alabama  Montgomery      Montgomery
# 2   1004       AL  Alabama      Shelby      Montevallo
# 3   1005       AL  Alabama  Montgomery      Montgomery
# 4   1007       AL  Alabama  Tallapoosa  Alexander City
#
#                                                 name  \
# 0  ALABAMA AGRICULTURAL & MECHANICAL UNIVERSITY  ...
# 1  FAULKNER UNIVERSITY                           ...
# 2  UNIVERSITY OF MONTEVALLO                      ...
# 3  ALABAMA STATE UNIVERSITY                      ...
# 4  CENTRAL ALABAMA COMMUNITY COLLEGE             ...
#
#                                              address  zipcode  zipext  \
# 0  4900 MERIDIAN STREET                          ...    35762    1357
# 1  5345 ATLANTA HIGHWAY                          ...    36109    3398
# 2  PALMER CIRCLE                                 ...    35115    6000
# ...

# %%
# we don't need the state abvr 2 column, so we can drop that
df = df.drop(columns = 'stateabv2')

# %%
# how many rows have null values?
df.isnull().any(axis=1).value_counts()
# Out:
# False    4097
# True      363
# dtype: int64

# %%
#remove puerto rico and virgin islands schools
df = df[df.state != 'Puerto Rico']
df = df[df.state != 'Virgin Islands']

# %%
# check states to make sure all domestic, leaving DC
df.state.value_counts().sort_index()
# Out:
# Alabama                  54
# Alaska                    8
# Arizona                  62
# Arkansas                 62
# California              457
# Colorado                 76
# Connecticut              52
# Delaware                 14
# District of Columbia     18
# Florida                 190
# Georgia                 106
# Hawaii                   18
# Idaho                    29
# Illinois                203
# Indiana                  80
# Iowa                     76
# Kansas                   64
# Kentucky                 65
# Louisiana                70
# Maine                    35
# Maryland                 64
# Massachusetts           131
# Michigan                116
# Minnesota                85
# Mississippi              36
# Missouri                132
# Montana                  22
# Nebraska                 36
# Nevada                   23
# New Hampshire            32
# New Jersey               98
# New Mexico               25
# New York                331
# ...

# %%
# looking for 51 states due to leaving DC
df.state.nunique()
# Out:
# 51

# %%
# check again to see how many nulls we eliminated by removing non-us schools
df.stateabv.isnull().value_counts()
# Out:
# False    4235
# True      190
# Name: stateabv, dtype: int64

# %%
# create df with just states and abvs
statesAndAbv = df[['state', 'stateabv']].copy()
statesAndAbv
# Out:
#            state stateabv
# 0        Alabama       AL
# 1        Alabama       AL
# 2        Alabama       AL
# 3        Alabama       AL
# 4        Alabama       AL
# ...          ...      ...
# 4455       Texas       TX
# 4456  California       CA
# 4457    New York       NY
# 4458       Texas       TX
# 4459  California       CA
#
# [4425 rows x 2 columns]

# %%
# copied a dictionary from the internet that has a mapping of all states and their abbreviations so we can fix the missing stateabvs
statesDict = {
        'AK': 'Alaska',
        'AL': 'Alabama',
        'AR': 'Arkansas',
        'AS': 'American Samoa',
        'AZ': 'Arizona',
        'CA': 'California',
        'CO': 'Colorado',
        'CT': 'Connecticut',
        'DC': 'District of Columbia',
        'DE': 'Delaware',
        'FL': 'Florida',
        'GA': 'Georgia',
        'GU': 'Guam',
        'HI': 'Hawaii',
        'IA': 'Iowa',
        'ID': 'Idaho',
        'IL': 'Illinois',
        'IN': 'Indiana',
        'KS': 'Kansas',
        'KY': 'Kentucky',
        'LA': 'Louisiana',
        'MA': 'Massachusetts',
        'MD': 'Maryland',
        'ME': 'Maine',
        'MI': 'Michigan',
        'MN': 'Minnesota',
        'MO': 'Missouri',
        'MP': 'Northern Mariana Islands',
        'MS': 'Mississippi',
        'MT': 'Montana',
        'NA': 'National',
        'NC': 'North Carolina',
        'ND': 'North Dakota',
        'NE': 'Nebraska',
        'NH': 'New Hampshire',
        'NJ': 'New Jersey',
        'NM': 'New Mexico',
        'NV': 'Nevada',
        'NY': 'New York',
        'OH': 'Ohio',
        'OK': 'Oklahoma',
        'OR': 'Oregon',
        'PA': 'Pennsylvania',
        'PR': 'Puerto Rico',
        'RI': 'Rhode Island',
        'SC': 'South Carolina',
        'SD': 'South Dakota',
        'TN': 'Tennessee',
        'TX': 'Texas',
        'UT': 'Utah',
        'VA': 'Virginia',
        'VI': 'Virgin Islands',
        'VT': 'Vermont',
        'WA': 'Washington',
        'WI': 'Wisconsin',
        'WV': 'West Virginia',
        'WY': 'Wyoming'
}

# create reversed dictionary if needed
statesDictReversed = {v: k for k, v in statesDict.items()}

# %%
# map state abv based on dict
statesAndAbv['stateabv'] = [statesDictReversed[x] 
                            if x in statesDictReversed 
                                else None for x in statesAndAbv.state]

# %%
statesAndAbv
# Out:
#            state stateabv
# 0        Alabama       AL
# 1        Alabama       AL
# 2        Alabama       AL
# 3        Alabama       AL
# 4        Alabama       AL
# ...          ...      ...
# 4455       Texas       TX
# 4456  California       CA
# 4457    New York       NY
# 4458       Texas       TX
# 4459  California       CA
#
# [4425 rows x 2 columns]

# %%
statesAndAbv.stateabv.isnull().value_counts()
# Out:
# False    4425
# Name: stateabv, dtype: int64

# %%
# add state abvs to main df
df.stateabv = statesAndAbv.stateabv

# %%
# how many rows have null values now?
df.isnull().any(axis=1).value_counts()
# Out:
# False    4259
# True      166
# dtype: int64

# %%
# select rows with null values
nullRows = df[df.isnull().any(axis = 1)]
nullRows
# Out:
#       opeid stateabv       state       county            city  \
# 0      1002       AL     Alabama      Madison          Normal
# 8      1013       AL     Alabama    Limestone          Tanner
# 99     1153       CA  California  Los Angeles      Northridge
# 151    1226       CA  California  Los Angeles  Woodland Hills
# 211    1317       CA  California    San Diego        La Jolla
# ...     ...      ...         ...          ...             ...
# 4449  42439       TX       Texas        Smith           Tyler
# 4456  42788       CA  California  Los Angeles       San Dimas
# 4457  42797       NY    New York        Bronx           Bronx
# 4458  42808       TX       Texas      El Paso         El Paso
# 4459  42817       CA  California  Los Angeles         Compton
#
#                                                    name  \
# 0     ALABAMA AGRICULTURAL & MECHANICAL UNIVERSITY  ...
# 8     CALHOUN COMMUNITY COLLEGE                     ...
# ...

# %%
# Which cols have null values in df
df.columns[df.isnull().any()]
# Out:
# Index(['num2', 'denom2', 'drate2', 'prate2', 'num3', 'denom3', 'drate3',
#        'prate3', 'population', 'density', 'agemedian', 'male', 'female',
#        'married', 'familysize', 'incomehouseholdmedian',
#        'incomehouseholdsixfigure', 'homeownership', 'homevalue', 'rentmedian',
#        'educationcollegeorabove', 'laborforceparticipation',
#        'unemploymentrate', 'racewhite', 'raceblack', 'raceasian', 'racenative',
#        'racepacific', 'raceother', 'racemultiple'],
#       dtype='object')

# %%
# select values in San Diego, California
selectedCity = df.loc[(df['city'] == 'San Diego') & (df['state'] == 'California')]
selectedCity.head()
# Out:
#      opeid stateabv       state     county       city  \
# 98    1151       CA  California  San Diego  San Diego
# 176   1262       CA  California  San Diego  San Diego
# 182   1273       CA  California  San Diego  San Diego
# 183   1275       CA  California  San Diego  San Diego
# 565   1881       CA  California  San Diego  San Diego
#
#                                                   name  \
# 98   SAN DIEGO STATE UNIVERSITY                    ...
# 176  POINT LOMA NAZARENE UNIVERSITY                ...
# 182  SAN DIEGO CITY COLLEGE                        ...
# 183  SAN DIEGO MESA COLLEGE                        ...
# 565  ASHFORD UNIVERSITY                            ...
#
#                                                address  zipcode  zipext  \
# 98   5500 CAMPANILE DRIVE                          ...    92182    1690
# 176  3900 LOMALAND DRIVE                           ...    92106    2899
# 182  1313 PARK BOULEVARD                           ...    92101    4787
# ...

# %%
# export df with missing dataa
df.to_csv('/Users/dillorr/defaultRate/dillon/defaultRate/data/withNulls.csv', index=False)

# %%
# export df without missing data

withoutNulls = df.dropna()
# withoutNulls.to_csv('/Users/dillorr/defaultRate/dillon/defaultRate/data/withoutNulls.csv', index=False)
withoutNulls
# Out:
#       opeid stateabv         state      county            city  \
# 1      1003       AL       Alabama  Montgomery      Montgomery
# 2      1004       AL       Alabama      Shelby      Montevallo
# 3      1005       AL       Alabama  Montgomery      Montgomery
# 4      1007       AL       Alabama  Tallapoosa  Alexander City
# 5      1008       AL       Alabama   Limestone          Athens
# ...     ...      ...           ...         ...             ...
# 4450  42460       RI  Rhode Island  Providence        Cranston
# 4451  42485       TX         Texas       Bexar     San Antonio
# 4452  42527       HI        Hawaii    Honolulu        Honolulu
# 4454  42544       AR      Arkansas      Baxter   Mountain Home
# 4455  42636       TX         Texas       Bexar  Universal City
#
#                                                    name  \
# 1     FAULKNER UNIVERSITY                           ...
# 2     UNIVERSITY OF MONTEVALLO                      ...
# ...

# %%
df
# Out:
#       opeid stateabv       state       county            city  \
# 0      1002       AL     Alabama      Madison          Normal
# 1      1003       AL     Alabama   Montgomery      Montgomery
# 2      1004       AL     Alabama       Shelby      Montevallo
# 3      1005       AL     Alabama   Montgomery      Montgomery
# 4      1007       AL     Alabama   Tallapoosa  Alexander City
# ...     ...      ...         ...          ...             ...
# 4455  42636       TX       Texas        Bexar  Universal City
# 4456  42788       CA  California  Los Angeles       San Dimas
# 4457  42797       NY    New York        Bronx           Bronx
# 4458  42808       TX       Texas      El Paso         El Paso
# 4459  42817       CA  California  Los Angeles         Compton
#
#                                                    name  \
# 0     ALABAMA AGRICULTURAL & MECHANICAL UNIVERSITY  ...
# 1     FAULKNER UNIVERSITY                           ...
# ...
