# %%
import pandas as pd
import os

# %%
city = pd.read_csv('uscities.csv')
cdr = pd.read_csv('cdr.csv')

# %%
city.head(500)
# Out:
#     state abv    state      county             city       city_ascii city_alt  \
# 0          AL  Alabama    Chambers           Abanda           Abanda      NaN
# 1          AL  Alabama       Henry        Abbeville        Abbeville      NaN
# 2          AL  Alabama      Shelby    Abbot Springs    Abbot Springs      NaN
# 3          AL  Alabama    Cleburne             Abel             Abel      NaN
# 4          AL  Alabama        Bibb      Abercrombie      Abercrombie      NaN
# ..        ...      ...         ...              ...              ...      ...
# 495        AL  Alabama      Coffee     Central City     Central City      NaN
# 496        AL  Alabama  Lauderdale  Central Heights  Central Heights      NaN
# 497        AL  Alabama      Dallas    Central Mills    Central Mills      NaN
# 498        AL  Alabama    Cherokee           Centre           Centre      NaN
# 499        AL  Alabama        Bibb      Centreville      Centreville      NaN
#
# ...

# %%
city.describe()
# Out:
#          county_fips
# count  107548.000000
# mean    30564.245992
# std     16000.419455
# min      1001.000000
# 25%     18141.000000
# 50%     31051.000000
# 75%     42091.000000
# max     78030.000000

# %%
cdr.head()
# Out:
#    OPEID state abv    state            city  \
# 0  41872        AL  Alabama     Albertville
# 1   1007        AL  Alabama  Alexander City
# 2   1008        AL  Alabama          Athens
# 3   1009        AL  Alabama          Auburn
# 4   1060        AL  Alabama     Bay Minette
#
#                                                 Name  \
# 0  NEW BEGINNING COLLEGE OF COSMETOLOGY          ...
# 1  CENTRAL ALABAMA COMMUNITY COLLEGE             ...
# 2  ATHENS STATE UNIVERSITY                       ...
# 3  AUBURN UNIVERSITY                             ...
# 4  COASTAL ALABAMA COMMUNITY COLLEGE             ...
#
#                                              Address  Zip Code  Zip Ext  \
# 0  421 MARTLING ROAD                             ...     35951        0
# 1  1675 CHEROKEE ROAD                            ...     35010        0
# 2  300 NORTH BEATY STREET                        ...     35611     1999
# 3  107 SAMFORD HALL                              ...     36849     5113
# ...

# %%
cdr.describe()
# Out:
#               OPEID  Prog\nLength  School\nType  Year 1       \nNum 1  \
# count   4811.000000   4811.000000   4811.000000  4811.0   4811.000000
# mean   14918.618582      5.993141      2.181667  2016.0     88.851174
# std    14369.768937      2.044656      1.147828     0.0    303.833076
# min     1002.000000      1.000000      1.000000  2016.0      0.000000
# 25%     2876.500000      5.000000      1.000000  2016.0      5.000000
# 50%     8221.000000      6.000000      2.000000  2016.0     21.000000
# 75%    25458.000000      8.000000      3.000000  2016.0     80.000000
# max    42817.000000     12.000000      7.000000  2016.0  13717.000000
#
#            \nDenom 1      DRate 1  Ethnic Code       Region  \
# count    4811.000000  4811.000000  4811.000000  4811.000000
# mean      944.406984     9.772584     4.879235     5.515277
# std      2590.405634     7.486622     0.540046     2.858173
# min         2.000000     0.000000     1.000000     1.000000
# ...

# %%
cc = pd.merge(cdr, city,'left', on=['state', 'city'])

# %%
cc.head()
# Out:
#    OPEID state abv_x    state            city  \
# 0  41872          AL  Alabama     Albertville
# 1   1007          AL  Alabama  Alexander City
# 2   1008          AL  Alabama          Athens
# 3   1009          AL  Alabama          Auburn
# 4   1060          AL  Alabama     Bay Minette
#
#                                                 Name  \
# 0  NEW BEGINNING COLLEGE OF COSMETOLOGY          ...
# 1  CENTRAL ALABAMA COMMUNITY COLLEGE             ...
# 2  ATHENS STATE UNIVERSITY                       ...
# 3  AUBURN UNIVERSITY                             ...
# 4  COASTAL ALABAMA COMMUNITY COLLEGE             ...
#
#                                              Address  Zip Code  Zip Ext  \
# 0  421 MARTLING ROAD                             ...     35951        0
# 1  1675 CHEROKEE ROAD                            ...     35010        0
# 2  300 NORTH BEATY STREET                        ...     35611     1999
# ...

# %%
cc.to_csv('cdr_city.csv') # save cdr and city data

# %%
census = pd.read_csv('census.csv')
cdr_city = pd.read_csv('cdr_city.csv')

# %%
census.head(5000)
# Out:
#       state id    state  county id    county  SUMLEV  SEX  ORIGIN  AGEGRP  \
# 0            1  Alabama          1   Autauga      50    1       1       1
# 1            1  Alabama          1   Autauga      50    1       1       1
# 2            1  Alabama          1   Autauga      50    1       1       1
# 3            1  Alabama          1   Autauga      50    1       1       1
# 4            1  Alabama          1   Autauga      50    1       1       1
# ...        ...      ...        ...       ...     ...  ...     ...     ...
# 4995         1  Alabama         29  Cleburne      50    1       1       7
# 4996         1  Alabama         29  Cleburne      50    1       1       7
# 4997         1  Alabama         29  Cleburne      50    1       1       7
# 4998         1  Alabama         29  Cleburne      50    1       1       8
# 4999         1  Alabama         29  Cleburne      50    1       1       8
#
#       IMPRACE  RESPOP
# 0           1    1337
# 1           2     356
# ...

# %%
cdr_city.head()
# Out:
#    Column1  OPEID state abv_x    state   county          city  \
# 0        4   1060          AL  Alabama  Baldwin   Bay Minette
# 1       11  21706          AL  Alabama  Baldwin        Daphne
# 2       16  33614          AL  Alabama  Baldwin         Foley
# 3       42  41215          AL  Alabama  Baldwin  Orange Beach
# 4       23   1020          AL  Alabama  Calhoun  Jacksonville
#
#                                                 Name  \
# 0  COASTAL ALABAMA COMMUNITY COLLEGE             ...
# 1  UNITED STATES SPORTS ACADEMY                  ...
# 2  FORTIS COLLEGE                                ...
# 3  COLUMBIA SOUTHERN UNIVERSITY                  ...
# 4  JACKSONVILLE STATE UNIVERSITY                 ...
#
#                                              Address  Zip Code  Zip Ext  ...  \
# 0  1900 HIGHWAY 31 SOUTH                         ...     36507     2698  ...
# 1  ONE ACADEMY DRIVE                             ...     36526     7055  ...
# ...

# %%
census.describe()
# Out:
#            state id     county id     SUMLEV           SEX        ORIGIN  \
# count  1.048575e+06  1.048575e+06  1048575.0  1.048575e+06  1.048575e+06
# mean   2.530493e+01  7.888900e+01       50.0  1.503841e+00  1.351048e+00
# std    1.345451e+01  6.259591e+01        0.0  4.999855e-01  4.772981e-01
# min    1.000000e+00  1.000000e+00       50.0  1.000000e+00  1.000000e+00
# 25%    1.300000e+01  2.900000e+01       50.0  1.000000e+00  1.000000e+00
# 50%    2.600000e+01  6.900000e+01       50.0  2.000000e+00  1.000000e+00
# 75%    3.700000e+01  1.130000e+02       50.0  2.000000e+00  2.000000e+00
# max    4.800000e+01  5.100000e+02       50.0  2.000000e+00  2.000000e+00
#
#              AGEGRP       IMPRACE        RESPOP
# count  1.048575e+06  1.048575e+06  1.048575e+06
# mean   7.970298e+00  6.774634e+00  2.542757e+02
# std    4.833927e+00  6.091926e+00  1.862311e+03
# min    1.000000e+00  1.000000e+00  1.000000e+00
# 25%    4.000000e+00  2.000000e+00  1.000000e+00
# ...

# %%
census_sex1 = census[census.SEX == 1]
census_sex2 = census[census.SEX == 2]

# %%
census_sex1.describe()
# Out:
#             state id      county id    SUMLEV       SEX         ORIGIN  \
# count  520260.000000  520260.000000  520260.0  520260.0  520260.000000
# mean       25.297674      78.914381      50.0       1.0       1.355201
# std        13.459186      62.662009       0.0       0.0       0.478575
# min         1.000000       1.000000      50.0       1.0       1.000000
# 25%        13.000000      29.000000      50.0       1.0       1.000000
# 50%        26.000000      69.000000      50.0       1.0       1.000000
# 75%        37.000000     113.000000      50.0       1.0       2.000000
# max        48.000000     510.000000      50.0       1.0       2.000000
#
#               AGEGRP        IMPRACE         RESPOP
# count  520260.000000  520260.000000  520260.000000
# mean        7.889123       6.711590     251.573150
# std         4.791265       6.054905    1857.148397
# min         1.000000       1.000000       1.000000
# 25%         4.000000       2.000000       1.000000
# ...

# %%
census_sex2.describe()
# Out:
#             state id      county id    SUMLEV       SEX         ORIGIN  \
# count  528315.000000  528315.000000  528315.0  528315.0  528315.000000
# mean       25.312070      78.863998      50.0       2.0       1.346958
# std        13.449915      62.530800       0.0       0.0       0.476003
# min         1.000000       1.000000      50.0       2.0       1.000000
# 25%        13.000000      29.000000      50.0       2.0       1.000000
# 50%        26.000000      69.000000      50.0       2.0       1.000000
# 75%        37.000000     113.000000      50.0       2.0       2.000000
# max        48.000000     510.000000      50.0       2.0       2.000000
#
#               AGEGRP        IMPRACE         RESPOP
# count  528315.000000  528315.000000  528315.000000
# mean        8.050235       6.836717     256.937091
# std         4.874257       6.127535    1867.379527
# min         1.000000       1.000000       1.000000
# 25%         4.000000       2.000000       1.000000
# ...

# %%
census_sex1.to_csv('census_sex1.csv')
census_sex2.to_csv('census_sex2.csv')

# %%
cc.head()
# Out:
#    OPEID state abv_x    state            city  \
# 0  41872          AL  Alabama     Albertville
# 1   1007          AL  Alabama  Alexander City
# 2   1008          AL  Alabama          Athens
# 3   1009          AL  Alabama          Auburn
# 4   1060          AL  Alabama     Bay Minette
#
#                                                 Name  \
# 0  NEW BEGINNING COLLEGE OF COSMETOLOGY          ...
# 1  CENTRAL ALABAMA COMMUNITY COLLEGE             ...
# 2  ATHENS STATE UNIVERSITY                       ...
# 3  AUBURN UNIVERSITY                             ...
# 4  COASTAL ALABAMA COMMUNITY COLLEGE             ...
#
#                                              Address  Zip Code  Zip Ext  \
# 0  421 MARTLING ROAD                             ...     35951        0
# 1  1675 CHEROKEE ROAD                            ...     35010        0
# 2  300 NORTH BEATY STREET                        ...     35611     1999
# ...

# %%
cdr_city.head()
# Out:
#    Column1  OPEID state abv_x    state   county          city  \
# 0        4   1060          AL  Alabama  Baldwin   Bay Minette
# 1       11  21706          AL  Alabama  Baldwin        Daphne
# 2       16  33614          AL  Alabama  Baldwin         Foley
# 3       42  41215          AL  Alabama  Baldwin  Orange Beach
# 4       23   1020          AL  Alabama  Calhoun  Jacksonville
#
#                                                 Name  \
# 0  COASTAL ALABAMA COMMUNITY COLLEGE             ...
# 1  UNITED STATES SPORTS ACADEMY                  ...
# 2  FORTIS COLLEGE                                ...
# 3  COLUMBIA SOUTHERN UNIVERSITY                  ...
# 4  JACKSONVILLE STATE UNIVERSITY                 ...
#
#                                              Address  Zip Code  Zip Ext  ...  \
# 0  1900 HIGHWAY 31 SOUTH                         ...     36507     2698  ...
# 1  ONE ACADEMY DRIVE                             ...     36526     7055  ...
# ...

# %%
all_df = pd.merge(census, cdr_city,'left', on=['state', 'county'])
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-78-14a6a4ab87db> in <module>
# ----> 1 all_df = pd.merge(census, cdr_city,'left', on=['state', 'county'])
#
# ~\AppData\Local\Programs\Python\Python38-32\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      86         validate=validate,
#      87     )
# ---> 88     return op.get_result()
#      89
#      90
#
# ~\AppData\Local\Programs\Python\Python38-32\lib\site-packages\pandas\core\reshape\merge.py in get_result(self)
#     653         rindexers = {1: right_indexer} if right_indexer is not None else {}
#     654
# --> 655         result_data = concatenate_block_managers(
#     656             [(ldata, lindexers), (rdata, rindexers)],
# ...
